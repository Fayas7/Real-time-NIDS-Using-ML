# %% [markdown]
# EXPLARATORY DATA ANALYSIS

# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the preprocessed training data

# %%
train_data = pd.read_csv(r'C:\Users\fayaz\Documents\NIDS_IMPLEMENTATION\data\X_train_processed.csv')
labels = pd.read_csv(r'C:\Users\fayaz\Documents\NIDS_IMPLEMENTATION\data\y_train_processed.csv')

# %%
# Combine features and labels for EDA
train_data['Label'] = labels

# %%
# Display the first few rows of the dataset
train_data.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0         -0.428320      -0.390046          -0.012638               -0.011523
# 1         -0.429802      -0.384585          -0.011793               -0.010888
# 2          2.996805      -0.390045          -0.012638               -0.011523
# 3          2.268542      -0.390046          -0.011793               -0.012158
# 4         -0.408397      -0.242401          -0.009258               -0.011523
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                    -0.069082                    -0.009421
# 1                    -0.061159                    -0.009403
# 2                    -0.069082                    -0.009421
# 3                    -0.068340                    -0.009422
# 4                    -0.053111                    -0.009410
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0              -0.350016              -0.435972               -0.441739
# 1              -0.287217               0.319380               -0.138746
# 2              -0.350016              -0.435972               -0.441739
# 3              -0.350016              -0.435972               -0.441739
# 4              -0.263397              -0.435972               -0.222330
#
#    Fwd Packet Length Std  ...  min_seg_size_forward  Active Mean  Active Std  \
# 0              -0.331533  ...             -0.878564    -0.118275   -0.124699
# 1              -0.331533  ...              0.380337    -0.118275   -0.124699
# 2              -0.331533  ...             -0.878564    -0.118275   -0.124699
# 3              -0.331533  ...             -0.878564    -0.118275   -0.124699
# 4              -0.190098  ...             -0.878564    -0.118275   -0.124699
#
#    Active Max  Active Min  Idle Mean  Idle Std  Idle Max  Idle Min   Label
# 0   -0.163287   -0.087724  -0.284124 -0.075514 -0.285613 -0.275957  BENIGN
# 1   -0.163287   -0.087724  -0.284124 -0.075514 -0.285613 -0.275957  BENIGN
# 2   -0.163287   -0.087724  -0.284124 -0.075514 -0.285613 -0.275957  BENIGN
# 3   -0.163287   -0.087724  -0.284124 -0.075514 -0.285613 -0.275957  BENIGN
# 4   -0.163287   -0.087724  -0.284124 -0.075514 -0.285613 -0.275957  BENIGN
#
# [5 rows x 79 columns]

# %%
# Check for missing values
missing_values = train_data.isnull().sum()
print("Missing values in training data:\n", missing_values[missing_values > 0])
# Out:
# Missing values in training data:
#  Series([], dtype: int64)

# %%
# Summary statistics
summary_statistics = train_data.describe()
print("Summary statistics:\n", summary_statistics)
# Out:
# Summary statistics:
#         Destination Port  Flow Duration  Total Fwd Packets  \
# count      1.533290e+05   1.533290e+05       1.533290e+05
# mean       8.415535e-17   1.334622e-17       1.733155e-17
# std        1.000003e+00   1.000003e+00       1.000003e+00
# min       -4.327112e-01  -3.900459e-01      -1.263825e-02
# 25%       -4.298024e-01  -3.900399e-01      -1.263825e-02
# 50%       -4.283205e-01  -3.890619e-01      -1.179317e-02
# 75%       -4.083974e-01  -3.643744e-01      -1.010302e-02
# max        3.163819e+00   3.368231e+00       1.696396e+02
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# count            1.533290e+05                 1.533290e+05
# mean             2.724854e-17                 3.457043e-17
# std              1.000003e+00                 1.000003e+00
# min             -1.215770e-02                -6.982524e-02
# 25%             -1.152261e-02                -6.598712e-02
# 50%             -1.088753e-02                -6.140613e-02
# 75%             -1.088753e-02                -5.150131e-02
# max              1.718965e+02                 1.481558e+02
#
#        Total Length of Bwd Packets  Fwd Packet Length Max  \
# count                 1.533290e+05           1.533290e+05
# mean                  5.143857e-17           5.820436e-17
# std                   1.000003e+00           1.000003e+00
# min                  -9.422277e-03          -3.630090e-01
# 25%                  -9.420632e-03          -3.132031e-01
# 50%                  -9.385531e-03          -2.742247e-01
# 75%                  -9.332330e-03          -2.330807e-01
# max                   1.719327e+02           5.022241e+01
#
#        Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std  \
# count           1.533290e+05            1.533290e+05           1.533290e+05
# mean            1.522304e-17            1.823057e-16           1.992665e-17
# std             1.000003e+00            1.000003e+00           1.000003e+00
# min            -5.922515e-01           -5.044275e-01          -3.315325e-01
# 25%            -5.922515e-01           -4.164995e-01          -3.315325e-01
# 50%            -4.359718e-01           -1.074016e-01          -3.315325e-01
# 75%             4.756599e-01            1.797497e-02          -2.057473e-01
# max             4.444235e+01            4.320036e+01           3.806563e+01
#
#        ...  act_data_pkt_fwd  min_seg_size_forward   Active Mean  \
# count  ...      1.533290e+05          1.533290e+05  1.533290e+05
# mean   ...      1.362427e-17         -3.090485e-16  1.760960e-17
# std    ...      1.000003e+00          1.000003e+00  1.000003e+00
# min    ...     -1.118093e-02         -4.025816e+00 -1.182752e-01
# 25%    ...     -1.118093e-02         -8.785639e-01 -1.182752e-01
# 50%    ...     -1.030041e-02         -8.785639e-01 -1.182752e-01
# 75%    ...     -8.539356e-03          1.009787e+00 -1.182752e-01
# max    ...      1.694820e+02          5.415941e+00  1.636498e+02
#
#          Active Std    Active Max    Active Min     Idle Mean      Idle Std  \
# count  1.533290e+05  1.533290e+05  1.533290e+05  1.533290e+05  1.533290e+05
# mean   1.183551e-16  8.332121e-17  6.839939e-17 -1.306818e-17  5.361660e-17
# std    1.000003e+00  1.000003e+00  1.000003e+00  1.000003e+00  1.000003e+00
# min   -1.246991e-01 -1.632873e-01 -8.772419e-02 -2.841242e-01 -7.551374e-02
# 25%   -1.246991e-01 -1.632873e-01 -8.772419e-02 -2.841242e-01 -7.551374e-02
# 50%   -1.246991e-01 -1.632873e-01 -8.772419e-02 -2.841242e-01 -7.551374e-02
# 75%   -1.246991e-01 -1.632873e-01 -8.772419e-02 -2.841242e-01 -7.551374e-02
# max    1.695012e+02  1.019228e+02  1.803646e+02  8.954425e+00  4.241311e+01
#
#            Idle Max      Idle Min
# count  1.533290e+05  1.533290e+05
# mean   3.067778e-17  3.072412e-17
# std    1.000003e+00  1.000003e+00
# min   -2.856132e-01 -2.759571e-01
# 25%   -2.856132e-01 -2.759571e-01
# 50%   -2.856132e-01 -2.759571e-01
# 75%   -2.856132e-01 -2.759571e-01
# max    8.772980e+00  9.066258e+00
#
# [8 rows x 78 columns]

# %%
# Visualize the distribution of the target variable
plt.figure(figsize=(8, 5))
sns.countplot(x='Label', data=train_data)
plt.title('Distribution of Target Variable')
plt.xlabel('Label')
plt.ylabel('Count')
plt.show()

# %%
# Visualize the distribution of numerical features
numerical_cols = train_data.select_dtypes(include=['float64', 'int64']).columns

# %%
plt.figure(figsize=(20, 15))  # Increase the figure size
num_cols = len(numerical_cols)
rows = (num_cols // 4) + (num_cols % 4 > 0)  # Calculate the number of rows needed

for i, col in enumerate(numerical_cols):
    plt.subplot(rows, 4, i + 1)  # Adjust the number of rows as needed
    sns.histplot(train_data[col], bins=30, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)  # Add x-label for clarity
    plt.ylabel('Frequency')  # Add y-label for clarity

# Adjust layout
plt.subplots_adjust(hspace=0.4, wspace=0.4)  # Adjust space between subplots
plt.tight_layout()  # Apply tight layout
plt.show()
# Out:
# C:\Users\fayaz\AppData\Local\Temp\ipykernel_13364\2767390669.py:14: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()  # Apply tight layout

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))

# Select only numeric columns for correlation
numeric_data = train_data.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Create the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# #EXPLARATORY DATA ANALYSIS SUCCESSFULL
